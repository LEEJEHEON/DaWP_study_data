# %%
from PIL import Image

# %% [markdown]
# # Lecture 9-1

# %% [markdown]
# Neural Nets 로 XOR을 풀이

# %% [markdown]
# XOR = 1이 홀수 개면 1

# %% [markdown]
# X1과 X2를 INPUT 하여 W값과 b의 값으로 처리를 하고 sigmoid를 하여 y1 값을 구함 <br>
# 이것을 계속 연결함 (y1과 y2로 한번더 처리하여 y햇을 만듬)<br>

# %%
Image.open('xor1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=804x439 at 0x1FEBC7D3EB8>

# %% [markdown]
# 이 과정을 전체 그림으로 표현

# %%
Image.open('xor2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=560x370 at 0x1FEBC907390>

# %% [markdown]
# weight 과 bios 를 한개로 줄일 수 있다.

# %%
Image.open('xor3.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=824x372 at 0x1FEBC907438>

# %% [markdown]
# 코드로 바꾸면<br>
# K = tf.sigmoid(tf.matmul(X,W1) +b1)<br>
# hypothesis = tf.sigmoid(tf.matmul(K,W2)+b2)

# %% [markdown]
# # lec9-x

# %% [markdown]
#  f(x) = 3 은 상수 함수는 0이 된다.<br>
#  f(x) = x 는 1 <br>
#  f(x) = 2x 는 2가 된다.

# %% [markdown]
# f(x,y) = xy*(Partial)f/(Partial) x  는 y<br>
# f(x,y) = xy*(Partial)f/(Partial) y  는 x

# %% [markdown]
# f(x,y) = x+y,(Partial)f/(Partial) x <br>
#   -> y는 상수 이고 x는 미분하면 1  = 1<br>
#   f(x,y) = x+y,(Partial)f/(Partial) y <br>
#   -> y는 상수 이고 x는 미분하면 1  = 1<br>

# %% [markdown]
# f(g(x))  x가 f에 영향을 주는 것은 무엇인가?<br>
# chain rull (중요)<br>
# af/ax = (af/ag) * (ag/ax)

# %% [markdown]
# # lec9-2 딥넷트윅 학습

# %% [markdown]
# XOR 때 사용했던 W 과 B 의 값을 어떻게 구할 것인가??<br>
# GradientDescentOptimizer 알고리즘을 사용

# %% [markdown]
#  Back propagation (chain rule)<br>
#      f =wx +b , g=wx , f = g+b
